# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Requires PANDAS
# ```
# $ pip install pandas
# ```

# %% [markdown]
# Requires MATPLOTLIB
# ```
# $ pip install matplotlib
# ```

# %%
df = pd.read_csv('./inputs/Environmental_Data_Deep_Moor_2013.csv')

# %%
# rows for first week of January
df_week1 = df[df['date'].between('2013_01_01','2013_01_07')]

# %%
df_week2 = df[df['date'].between('2013_01_08','2013_01_15')]

# %%
plt.plot(df_week1['Air_Temp'])

# %%
plt.plot(df_week2['Air_Temp'])
